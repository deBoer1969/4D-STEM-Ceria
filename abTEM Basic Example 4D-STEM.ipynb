# %%
# %config InlineBackend.rc = {"figure.dpi": 72, "figure.figsize": (6.0, 4.0)}
# %matplotlib inline

import abtem
import ase
import matplotlib.pyplot as plt
from ase.io import write

# %%
abtem.config.set({"device": "cpu"})

# %%
atoms = ase.build.mx2(vacuum=2)

atoms = abtem.orthogonalize_cell(atoms)

atoms *= (3, 2, 1)

abtem.show_atoms(atoms)
# Out:
# (<Figure size 432x288 with 1 Axes>,
#  <AxesSubplot:xlabel='x [Å]', ylabel='y [Å]'>)

# %%
potential = abtem.Potential(atoms, sampling=0.05)

probe = abtem.Probe(energy=80e3, semiangle_cutoff=30)
probe.grid.match(potential)

# %%
grid_scan = abtem_GridScan_from_fractional_coordinates(
    potential,
    start=[0, 0],
    end=[1 / 3, 1 / 2],
    sampling=probe.aperture.nyquist_sampling,
)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[9], line 1
# ----> 1 grid_scan = abtem_GridScan_from_fractional_coordinates(
#       2     potential,
#       3     start=[0, 0],
#       4     end=[1 / 3, 1 / 2],
#       5     sampling=probe.aperture.nyquist_sampling,
#       6 )
#
# NameError: name 'abtem_GridScan_from_fractional_coordinates' is not defined

# %%
detector = abtem.PixelatedDetector()

measurements = probe.scan(potential, scan=grid_scan, detectors=detector)
measurements.array
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[6], line 3
#       1 detector = abtem.PixelatedDetector()
# ----> 3 measurements = probe.scan(potential, scan=grid_scan, detectors=detector)
#       4 measurements.array
#
# NameError: name 'grid_scan' is not defined

# %%
measurements.compute()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[7], line 1
# ----> 1 measurements.compute()
#
# NameError: name 'measurements' is not defined

# %%
filtered_measurements = measurements.gaussian_source_size(.3)

center_of_mass = filtered_measurements.center_of_mass()

interpolated_center_of_mass = center_of_mass.interpolate(0.05).tile((3, 2))

interpolated_center_of_mass.show(cbar=True, vmax=0.04, vmin=0);
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[8], line 1
# ----> 1 filtered_measurements = measurements.gaussian_source_size(.3)
#       3 center_of_mass = filtered_measurements.center_of_mass()
#       5 interpolated_center_of_mass = center_of_mass.interpolate(0.05).tile((3, 2))
#
# NameError: name 'measurements' is not defined
